# %%
import pandas as pd
from utils import read_csv_as_dataframe

# %%
df = read_csv_as_dataframe('data/preanes_2014-20_NOimputed_full_for_cpx_20240317.csv')
df
# Out:
# End of file reached: data/preanes_2014-20_NOimputed_full_for_cpx_20240317.csv
#                       病歷編號 性別                          術前診斷  \
# 0            0  1000001424  女             left ureter stone
# 1            2  1000000747  男                   UCUB s/p OP
# 2            4  1000000747  男                   UCUB s/p OP
# 3            6  1000000747  男                          UCUB
# 4            8  1000000747  男    cT1 UCUB s/p bipolar TURBt
# ...        ...         ... ..                           ...
# 110247  602904  1002636175  女                  appendicitis
# 110248  602908  1002638819  男                       CHR,NSD
# 110249  602909  1002639646  男  Right distal fibula fracture
# 110250  602910  1002639659  男       left putaminal ICH, IVH
# 110251  602914  1002642951  男                       CHR,NSD
#
#                      預計手術日期 Pre_OP_Location         生日     身高    體重  年齡  ...  \
# 0       2016-03-02 00:00:00        床號12G161  1951-3-18    157    75  65  ...
# ...

# %%
df.體重.value_counts()
# Out:
# 體重
# 60       4647
# 65       4002
# 70       3958
# 55       2961
# 75       2941
#          ...
# 49.15       1
# 31.1        1
# 46.50       1
# 54-55       1
# 7.075       1
# Name: count, Length: 1302, dtype: int64

# %% [markdown]
# # 請分析體重欄位的所有值的可能與出現的次數

# %%
weights_unique = df.體重.unique()
pd.DataFrame(weights_unique).to_csv('weights.csv', index=False)
weights_orig = list(weights_unique)

# %% [markdown]
# # 請盡可能來整理體重欄位

# %%
def weight(x)
    # 寫你的程式
    return result

df.體重 = df.體重.apply(weight)

# %% [markdown]
# # 針對體重欄位，請輸出檔案 weights_imputed.csv，比較整理前後的值

# %%
weights_imputed = [ weight(w) for w in weights_orig]

# %%
pd.DataFrame({'weights_orig': weights_orig, 'weights_imputed': weights_imputed}, index=None).to_csv('weights_comparisons.csv', index=False)
