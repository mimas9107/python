# %% [markdown]
# # 第9章：透過分組來進行聚合、過濾和轉換

# %% [markdown]
# ## 9.1 進行簡單的分組及聚合運算

# %%
import pandas as pd
import numpy as np
pd.set_option('max_columns', 4, 'max_rows', 10)

flights = pd.read_csv('data/flights.csv')
flights.head()
# Out:
#    MONTH  DAY  ...  DIVERTED CANCELLED
# 0      1    1  ...         0         0
# 1      1    1  ...         0         0
# 2      1    1  ...         0         0
# 3      1    1  ...         0         0
# 4      1    1  ...         0         0
#
# [5 rows x 14 columns]

# %%
(flights
     .groupby('AIRLINE')
     .agg({'ARR_DELAY':'mean'})
)
# Out:
#          ARR_DELAY
# AIRLINE
# AA        5.542661
# AS       -0.833333
# B6        8.692593
# DL        0.339691
# EV        7.034580
# ...            ...
# OO        7.593463
# UA        7.765755
# US        1.681105
# VX        5.348884
# WN        6.397353
#
# [14 rows x 1 columns]

# %%
(flights
     .groupby('AIRLINE')
     ['ARR_DELAY']
     .agg('mean')
)
# Out:
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
#         ...
# OO    7.593463
# UA    7.765755
# US    1.681105
# VX    5.348884
# WN    6.397353
# Name: ARR_DELAY, Length: 14, dtype: float64

# %%
(flights
     .groupby('AIRLINE')
     ['ARR_DELAY']
     .agg(np.mean)
)
# Out:
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
#         ...
# OO    7.593463
# UA    7.765755
# US    1.681105
# VX    5.348884
# WN    6.397353
# Name: ARR_DELAY, Length: 14, dtype: float64

# %%
(flights
     .groupby('AIRLINE')
     ['ARR_DELAY']
     .mean()
)
# Out:
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
#         ...
# OO    7.593463
# UA    7.765755
# US    1.681105
# VX    5.348884
# WN    6.397353
# Name: ARR_DELAY, Length: 14, dtype: float64

# %%
# (flights
#    .groupby('AIRLINE')
#    ['ARR_DELAY']
#    .agg(np.sqrt)
# )

# %% [markdown]
# ## 9.2 對多個欄位執行分組及聚合運算

# %%
(flights
    .groupby(['AIRLINE', 'WEEKDAY'])
    ['CANCELLED'] 
    .agg('sum')
)
# Out:
# AIRLINE  WEEKDAY
# AA       1          41
#          2           9
#          3          16
#          4          20
#          5          18
#                     ..
# WN       3          18
#          4          10
#          5           7
#          6          10
#          7           7
# Name: CANCELLED, Length: 98, dtype: int64

# %%
(flights
    .groupby(['AIRLINE', 'WEEKDAY']) 
    ['CANCELLED', 'DIVERTED']
    .agg(['sum', 'mean'])
)
# Out:
# <ipython-input-8-fb02002e28ce>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   (flights
#                 CANCELLED           DIVERTED
#                       sum      mean      sum      mean
# AIRLINE WEEKDAY
# AA      1              41  0.032106        6  0.004699
#         2               9  0.007341        2  0.001631
#         3              16  0.011949        2  0.001494
#         4              20  0.015004        5  0.003751
#         5              18  0.014151        1  0.000786
# ...                   ...       ...      ...       ...
# WN      3              18  0.014118        2  0.001569
#         4              10  0.007911        4  0.003165
#         5               7  0.005828        0  0.000000
#         6              10  0.010132        3  0.003040
#         7               7  0.006066        3  0.002600
#
# [98 rows x 4 columns]

# %%
(flights
    .groupby(['ORG_AIR', 'DEST_AIR'])
    .agg({'CANCELLED':['sum', 'mean', 'size'],
          'AIR_TIME':['mean', 'var']})
)
# Out:
#                  CANCELLED            ...    AIR_TIME
#                        sum      mean  ...        mean         var
# ORG_AIR DEST_AIR                      ...
# ATL     ABE              0  0.000000  ...   96.387097   45.778495
#         ABQ              0  0.000000  ...  170.500000   87.866667
#         ABY              0  0.000000  ...   28.578947    6.590643
#         ACY              0  0.000000  ...   91.333333   11.466667
#         AEX              0  0.000000  ...   78.725000   47.332692
# ...                    ...       ...  ...         ...         ...
# SFO     SNA              4  0.032787  ...   64.059322   11.338331
#         STL              0  0.000000  ...  198.900000  101.042105
#         SUN              0  0.000000  ...   78.000000   25.777778
#         TUS              0  0.000000  ...  100.200000   35.221053
#         XNA              0  0.000000  ...  173.500000    0.500000
#
# [1130 rows x 5 columns]

# %%
(flights
    .groupby(['ORG_AIR', 'DEST_AIR'])
    .agg(sum_cancelled=pd.NamedAgg(column='CANCELLED', aggfunc='sum'),
         mean_cancelled=pd.NamedAgg(column='CANCELLED', aggfunc='mean'),
         size_cancelled=pd.NamedAgg(column='CANCELLED', aggfunc='size'),
         mean_air_time=pd.NamedAgg(column='AIR_TIME', aggfunc='mean'),
         var_air_time=pd.NamedAgg(column='AIR_TIME', aggfunc='var'))
)
# Out:
#                   sum_cancelled  mean_cancelled  ...  mean_air_time  \
# ORG_AIR DEST_AIR                                 ...
# ATL     ABE                   0        0.000000  ...      96.387097
#         ABQ                   0        0.000000  ...     170.500000
#         ABY                   0        0.000000  ...      28.578947
#         ACY                   0        0.000000  ...      91.333333
#         AEX                   0        0.000000  ...      78.725000
# ...                         ...             ...  ...            ...
# SFO     SNA                   4        0.032787  ...      64.059322
#         STL                   0        0.000000  ...     198.900000
#         SUN                   0        0.000000  ...      78.000000
#         TUS                   0        0.000000  ...     100.200000
#         XNA                   0        0.000000  ...     173.500000
#
#                   var_air_time
# ORG_AIR DEST_AIR
# ATL     ABE          45.778495
#         ABQ          87.866667
#         ABY           6.590643
#         ACY          11.466667
#         AEX          47.332692
# ...                        ...
# SFO     SNA          11.338331
#         STL         101.042105
#         SUN          25.777778
#         TUS          35.221053
#         XNA           0.500000
#
# [1130 rows x 5 columns]

# %%
res = (flights.groupby(['ORG_AIR', 'DEST_AIR'])
              .agg({'CANCELLED':['sum', 'mean', 'size'],
                    'AIR_TIME':['mean', 'var']})
)
res.columns
# Out:
# MultiIndex([('CANCELLED',  'sum'),
#             ('CANCELLED', 'mean'),
#             ('CANCELLED', 'size'),
#             ( 'AIR_TIME', 'mean'),
#             ( 'AIR_TIME',  'var')],
#            )

# %%
res_flat_column = res.columns.to_flat_index()
res_flat_column
# Out:
# Index([ ('CANCELLED', 'sum'), ('CANCELLED', 'mean'), ('CANCELLED', 'size'),
#         ('AIR_TIME', 'mean'),   ('AIR_TIME', 'var')],
#       dtype='object')

# %%
res.columns = ['_'.join(x) for x in res_flat_column]
res
# Out:
#                   CANCELLED_sum  CANCELLED_mean  ...  AIR_TIME_mean  \
# ORG_AIR DEST_AIR                                 ...
# ATL     ABE                   0        0.000000  ...      96.387097
#         ABQ                   0        0.000000  ...     170.500000
#         ABY                   0        0.000000  ...      28.578947
#         ACY                   0        0.000000  ...      91.333333
#         AEX                   0        0.000000  ...      78.725000
# ...                         ...             ...  ...            ...
# SFO     SNA                   4        0.032787  ...      64.059322
#         STL                   0        0.000000  ...     198.900000
#         SUN                   0        0.000000  ...      78.000000
#         TUS                   0        0.000000  ...     100.200000
#         XNA                   0        0.000000  ...     173.500000
#
#                   AIR_TIME_var
# ORG_AIR DEST_AIR
# ATL     ABE          45.778495
#         ABQ          87.866667
#         ABY           6.590643
#         ACY          11.466667
#         AEX          47.332692
# ...                        ...
# SFO     SNA          11.338331
#         STL         101.042105
#         SUN          25.777778
#         TUS          35.221053
#         XNA           0.500000
#
# [1130 rows x 5 columns]

# %%
def flatten_cols(df):
    df.columns = ['_'.join(x) for x in df.columns.to_flat_index()]
    return df

res = (flights
    .groupby(['ORG_AIR', 'DEST_AIR'])
    .agg({'CANCELLED':['sum', 'mean', 'size'],
          'AIR_TIME':['mean', 'var']})
    .pipe(flatten_cols)
)

res
# Out:
#                   CANCELLED_sum  CANCELLED_mean  ...  AIR_TIME_mean  \
# ORG_AIR DEST_AIR                                 ...
# ATL     ABE                   0        0.000000  ...      96.387097
#         ABQ                   0        0.000000  ...     170.500000
#         ABY                   0        0.000000  ...      28.578947
#         ACY                   0        0.000000  ...      91.333333
#         AEX                   0        0.000000  ...      78.725000
# ...                         ...             ...  ...            ...
# SFO     SNA                   4        0.032787  ...      64.059322
#         STL                   0        0.000000  ...     198.900000
#         SUN                   0        0.000000  ...      78.000000
#         TUS                   0        0.000000  ...     100.200000
#         XNA                   0        0.000000  ...     173.500000
#
#                   AIR_TIME_var
# ORG_AIR DEST_AIR
# ATL     ABE          45.778495
#         ABQ          87.866667
#         ABY           6.590643
#         ACY          11.466667
#         AEX          47.332692
# ...                        ...
# SFO     SNA          11.338331
#         STL         101.042105
#         SUN          25.777778
#         TUS          35.221053
#         XNA           0.500000
#
# [1130 rows x 5 columns]

# %%
res = (flights
    .assign(ORG_AIR=flights.ORG_AIR.astype('category'))
    .groupby(['ORG_AIR', 'DEST_AIR'])
    .agg({'CANCELLED':['sum', 'mean', 'size'],
          'AIR_TIME':['mean', 'var']})
)
res
# Out:
#                  CANCELLED       ...    AIR_TIME
#                        sum mean  ...        mean        var
# ORG_AIR DEST_AIR                 ...
# ATL     ABE            0.0  0.0  ...   96.387097  45.778495
#         ABI            NaN  NaN  ...         NaN        NaN
#         ABQ            0.0  0.0  ...  170.500000  87.866667
#         ABR            NaN  NaN  ...         NaN        NaN
#         ABY            0.0  0.0  ...   28.578947   6.590643
# ...                    ...  ...  ...         ...        ...
# SFO     TYS            NaN  NaN  ...         NaN        NaN
#         VLD            NaN  NaN  ...         NaN        NaN
#         VPS            NaN  NaN  ...         NaN        NaN
#         XNA            0.0  0.0  ...  173.500000   0.500000
#         YUM            NaN  NaN  ...         NaN        NaN
#
# [2710 rows x 5 columns]

# %%
res = (flights
    .assign(ORG_AIR=flights.ORG_AIR.astype('category'))
    .groupby(['ORG_AIR', 'DEST_AIR'], observed=True)
    .agg({'CANCELLED':['sum', 'mean', 'size'],
          'AIR_TIME':['mean', 'var']})
)
res
# Out:
#                  CANCELLED            ...    AIR_TIME
#                        sum      mean  ...        mean         var
# ORG_AIR DEST_AIR                      ...
# LAX     ABQ              1  0.018182  ...   89.259259   29.403215
#         ANC              0  0.000000  ...  307.428571   78.952381
#         ASE              1  0.038462  ...  102.920000  102.243333
#         ATL              0  0.000000  ...  224.201149  127.155837
#         AUS              0  0.000000  ...  150.537500   57.897310
# ...                    ...       ...  ...         ...         ...
# MSP     TTN              1  0.125000  ...  124.428571   57.952381
#         TUL              0  0.000000  ...   91.611111   63.075163
#         TUS              0  0.000000  ...  176.000000   32.000000
#         TVC              0  0.000000  ...   56.600000   10.300000
#         XNA              0  0.000000  ...   90.642857  115.939560
#
# [1130 rows x 5 columns]

# %% [markdown]
# ## 9.3 分組後刪除MultiIndex

# %%
flights = pd.read_csv('data/flights.csv')
airline_info = (flights
    .groupby(['AIRLINE', 'WEEKDAY'])
    .agg({'DIST':['sum', 'mean'],
          'ARR_DELAY':['min', 'max']}) 
    .astype(int)
)
airline_info
# Out:
#                     DIST       ARR_DELAY
#                      sum  mean       min  max
# AIRLINE WEEKDAY
# AA      1        1455386  1139       -60  551
#         2        1358256  1107       -52  725
#         3        1496665  1117       -45  473
#         4        1452394  1089       -46  349
#         5        1427749  1122       -41  732
# ...                  ...   ...       ...  ...
# WN      3         997213   782       -38  262
#         4        1024854   810       -52  284
#         5         981036   816       -44  244
#         6         823946   834       -41  290
#         7         945679   819       -45  261
#
# [98 rows x 4 columns]

# %%
airline_info.columns.get_level_values(0)
# Out:
# Index(['DIST', 'DIST', 'ARR_DELAY', 'ARR_DELAY'], dtype='object')

# %%
airline_info.columns.get_level_values(1)
# Out:
# Index(['sum', 'mean', 'min', 'max'], dtype='object')

# %%
airline_info.columns.to_flat_index()
# Out:
# Index([('DIST', 'sum'), ('DIST', 'mean'), ('ARR_DELAY', 'min'),
#        ('ARR_DELAY', 'max')],
#       dtype='object')

# %%
airline_info.columns = ['_'.join(x) for x in
    airline_info.columns.to_flat_index()]

airline_info
# Out:
#                  DIST_sum  DIST_mean  ARR_DELAY_min  ARR_DELAY_max
# AIRLINE WEEKDAY
# AA      1         1455386       1139            -60            551
#         2         1358256       1107            -52            725
#         3         1496665       1117            -45            473
#         4         1452394       1089            -46            349
#         5         1427749       1122            -41            732
# ...                   ...        ...            ...            ...
# WN      3          997213        782            -38            262
#         4         1024854        810            -52            284
#         5          981036        816            -44            244
#         6          823946        834            -41            290
#         7          945679        819            -45            261
#
# [98 rows x 4 columns]

# %%
airline_info.reset_index()
# Out:
#    AIRLINE  WEEKDAY  ...  ARR_DELAY_min  ARR_DELAY_max
# 0       AA        1  ...            -60            551
# 1       AA        2  ...            -52            725
# 2       AA        3  ...            -45            473
# 3       AA        4  ...            -46            349
# 4       AA        5  ...            -41            732
# ..     ...      ...  ...            ...            ...
# 93      WN        3  ...            -38            262
# 94      WN        4  ...            -52            284
# 95      WN        5  ...            -44            244
# 96      WN        6  ...            -41            290
# 97      WN        7  ...            -45            261
#
# [98 rows x 6 columns]

# %%
(flights
    .groupby(['AIRLINE', 'WEEKDAY'])
    .agg(dist_sum=pd.NamedAgg(column='DIST', aggfunc='sum'),
         dist_mean=pd.NamedAgg(column='DIST', aggfunc='mean'),
         arr_delay_min=pd.NamedAgg(column='ARR_DELAY', aggfunc='min'),
         arr_delay_max=pd.NamedAgg(column='ARR_DELAY', aggfunc='max'))
    .astype(int)
    .reset_index()
)
# Out:
#    AIRLINE  WEEKDAY  ...  arr_delay_min  arr_delay_max
# 0       AA        1  ...            -60            551
# 1       AA        2  ...            -52            725
# 2       AA        3  ...            -45            473
# 3       AA        4  ...            -46            349
# 4       AA        5  ...            -41            732
# ..     ...      ...  ...            ...            ...
# 93      WN        3  ...            -38            262
# 94      WN        4  ...            -52            284
# 95      WN        5  ...            -44            244
# 96      WN        6  ...            -41            290
# 97      WN        7  ...            -45            261
#
# [98 rows x 6 columns]

# %%
(flights
    .groupby(['AIRLINE'], as_index=False)
    ['DIST']
    .agg('mean')
    .round(0)
)
# Out:
#    AIRLINE    DIST
# 0       AA  1114.0
# 1       AS  1066.0
# 2       B6  1772.0
# 3       DL   866.0
# 4       EV   460.0
# ..     ...     ...
# 9       OO   511.0
# 10      UA  1231.0
# 11      US  1181.0
# 12      VX  1240.0
# 13      WN   810.0
#
# [14 rows x 2 columns]

# %% [markdown]
# ## 9.4 使用自訂的聚合函式來分組

# %%
college = pd.read_csv('data/college.csv')
(college
    .groupby('STABBR')
    ['UGDS']
    .agg(['mean', 'std'])
    .round(0)
)
# Out:
#           mean      std
# STABBR
# AK      2493.0   4052.0
# AL      2790.0   4658.0
# AR      1644.0   3143.0
# AS      1276.0      NaN
# AZ      4130.0  14894.0
# ...        ...      ...
# VT      1513.0   2194.0
# WA      2271.0   4124.0
# WI      2655.0   4615.0
# WV      1758.0   5957.0
# WY      2244.0   2745.0
#
# [59 rows x 2 columns]

# %%
def max_deviation(s):
    std_score = (s - s.mean()) / s.std()
    return std_score.abs().max()

# %%
(college
    .groupby('STABBR')
    ['UGDS']
    .agg(max_deviation)
    .round(1)
)
# Out:
# STABBR
# AK    2.6
# AL    5.8
# AR    6.3
# AS    NaN
# AZ    9.9
#      ...
# VT    3.8
# WA    6.6
# WI    5.8
# WV    7.2
# WY    2.8
# Name: UGDS, Length: 59, dtype: float64

# %%
(college
    .groupby('STABBR')
    ['UGDS', 'SATVRMID', 'SATMTMID']
    .agg(max_deviation)
    .round(1)
)
# Out:
# <ipython-input-28-fb803eab90b9>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   (college
#         UGDS  SATVRMID  SATMTMID
# STABBR
# AK       2.6       NaN       NaN
# AL       5.8       1.6       1.8
# AR       6.3       2.2       2.3
# AS       NaN       NaN       NaN
# AZ       9.9       1.9       1.4
# ...      ...       ...       ...
# VT       3.8       1.9       1.9
# WA       6.6       2.2       2.0
# WI       5.8       2.4       2.2
# WV       7.2       1.7       2.1
# WY       2.8       NaN       NaN
#
# [59 rows x 3 columns]

# %%
(college
    .groupby(['STABBR']) 
    ['UGDS'] 
    .agg([max_deviation, 'mean', 'std'])
    .round(1)
)
# Out:
#         max_deviation    mean      std
# STABBR
# AK                2.6  2493.2   4051.7
# AL                5.8  2789.9   4657.9
# AR                6.3  1644.1   3142.8
# AS                NaN  1276.0      NaN
# AZ                9.9  4130.5  14893.6
# ...               ...     ...      ...
# VT                3.8  1512.6   2193.6
# WA                6.6  2271.2   4123.7
# WI                5.8  2655.5   4615.5
# WV                7.2  1758.1   5957.2
# WY                2.8  2244.4   2744.7
#
# [59 rows x 3 columns]

# %%
max_deviation.__name__
# Out:
# 'max_deviation'

# %%
max_deviation.__name__ = 'Max Deviation'
(college
    .groupby(['STABBR', 'RELAFFIL']) 
    ['UGDS', 'SATVRMID', 'SATMTMID'] 
    .agg([max_deviation, 'mean', 'std'])
    .round(1)
)
# Out:
# <ipython-input-31-42a7cc7ba9cb>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   (college
#                          UGDS          ... SATMTMID
#                 Max Deviation    mean  ...     mean   std
# STABBR RELAFFIL                        ...
# AK     0                  2.1  3508.9  ...      NaN   NaN
#        1                  1.1   123.3  ...    503.0   NaN
# AL     0                  5.2  3248.8  ...    515.8  56.7
#        1                  2.4   979.7  ...    485.6  61.4
# AR     0                  5.8  1793.7  ...    503.6  39.0
# ...                       ...     ...  ...      ...   ...
# WI     0                  5.3  2879.1  ...    591.2  85.7
#        1                  3.4  1716.2  ...    526.6  42.5
# WV     0                  6.9  1873.9  ...    480.0  27.7
#        1                  1.3   716.4  ...    484.8  17.7
# WY     0                  2.8  2244.4  ...    540.0   NaN
#
# [112 rows x 9 columns]

# %% [markdown]
# ## 9.5 可接收多個參數的自訂聚合函式

# %%
def pct_between_1_3k(s):
    return (s.between(1_000, 3_000)
             .mean()* 100)

# %%
(college
    .groupby(['STABBR', 'RELAFFIL'])
    ['UGDS'] 
    .agg(pct_between_1_3k)
    .round(1)
)
# Out:
# STABBR  RELAFFIL
# AK      0           14.3
#         1            0.0
# AL      0           23.6
#         1           33.3
# AR      0           27.9
#                     ...
# WI      0           13.8
#         1           36.0
# WV      0           24.6
#         1           37.5
# WY      0           54.5
# Name: UGDS, Length: 112, dtype: float64

# %%
def pct_between(s, low, high):
    return s.between(low, high).mean() * 100

# %%
(college
    .groupby(['STABBR', 'RELAFFIL'])
    ['UGDS'] 
    .agg(pct_between, 1_000, 10_000)
    .round(1)
)
# Out:
# STABBR  RELAFFIL
# AK      0           42.9
#         1            0.0
# AL      0           45.8
#         1           37.5
# AR      0           39.7
#                     ...
# WI      0           31.0
#         1           44.0
# WV      0           29.2
#         1           37.5
# WY      0           72.7
# Name: UGDS, Length: 112, dtype: float64

# %%
(college
    .groupby(['STABBR', 'RELAFFIL'])
    ['UGDS'] 
    .agg(pct_between, low=1_000, high=10_000)
    .round(1)
)
# Out:
# STABBR  RELAFFIL
# AK      0           42.9
#         1            0.0
# AL      0           45.8
#         1           37.5
# AR      0           39.7
#                     ...
# WI      0           31.0
#         1           44.0
# WV      0           29.2
#         1           37.5
# WY      0           72.7
# Name: UGDS, Length: 112, dtype: float64

# %%
def between_n_m(n, m):
    def wrapper(ser):
        return pct_between(ser, n, m)
    wrapper.__name__ = f'between_{n}_{m}'
    return wrapper

(college
    .groupby(['STABBR', 'RELAFFIL'])
    ['UGDS'] 
    .agg([between_n_m(1_000, 10_000), 'max', 'mean'])
    .round(1)
)
# Out:
#                  between_1000_10000      max    mean
# STABBR RELAFFIL
# AK     0                       42.9  12865.0  3508.9
#        1                        0.0    275.0   123.3
# AL     0                       45.8  29851.0  3248.8
#        1                       37.5   3033.0   979.7
# AR     0                       39.7  21405.0  1793.7
# ...                             ...      ...     ...
# WI     0                       31.0  29302.0  2879.1
#        1                       44.0   8212.0  1716.2
# WV     0                       29.2  44924.0  1873.9
#        1                       37.5   1375.0   716.4
# WY     0                       72.7   9910.0  2244.4
#
# [112 rows x 3 columns]

# %% [markdown]
# ## 9.6 深入了解groupby物件

# %%
college = pd.read_csv('data/college.csv')
grouped = college.groupby(['STABBR', 'RELAFFIL'])
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
print([attr for attr in dir(grouped) if not
    attr.startswith('_')])
# Out:
# ['CITY', 'CURROPER', 'DISTANCEONLY', 'GRAD_DEBT_MDN_SUPP', 'HBCU', 'INSTNM', 'MD_EARN_WNE_P10', 'MENONLY', 'PCTFLOAN', 'PCTPELL', 'PPTUG_EF', 'RELAFFIL', 'SATMTMID', 'SATVRMID', 'STABBR', 'UG25ABV', 'UGDS', 'UGDS_2MOR', 'UGDS_AIAN', 'UGDS_ASIAN', 'UGDS_BLACK', 'UGDS_HISP', 'UGDS_NHPI', 'UGDS_NRA', 'UGDS_UNKN', 'UGDS_WHITE', 'WOMENONLY', 'agg', 'aggregate', 'all', 'any', 'apply', 'backfill', 'bfill', 'boxplot', 'corr', 'corrwith', 'count', 'cov', 'cumcount', 'cummax', 'cummin', 'cumprod', 'cumsum', 'describe', 'diff', 'dtypes', 'expanding', 'ffill', 'fillna', 'filter', 'first', 'get_group', 'groups', 'head', 'hist', 'idxmax', 'idxmin', 'indices', 'last', 'mad', 'max', 'mean', 'median', 'min', 'ndim', 'ngroup', 'ngroups', 'nth', 'nunique', 'ohlc', 'pad', 'pct_change', 'pipe', 'plot', 'prod', 'quantile', 'rank', 'resample', 'rolling', 'sem', 'shift', 'size', 'skew', 'std', 'sum', 'tail', 'take', 'transform', 'tshift', 'var']

# %%
grouped.ngroups
# Out:
# 112

# %%
groups = list(grouped.groups)
groups[:6]
# Out:
# [('AK', 0), ('AK', 1), ('AL', 0), ('AL', 1), ('AR', 0), ('AR', 1)]

# %%
grouped.get_group(('FL', 1))
# Out:
#                                          INSTNM             CITY  ...  \
# 712              The Baptist College of Florida       Graceville  ...
# 713                            Barry University            Miami  ...
# 714       Gooding Institute of Nurse Anesthesia      Panama City  ...
# 715                  Bethune-Cookman University    Daytona Beach  ...
# 724                  Johnson University Florida        Kissimmee  ...
# ...                                         ...              ...  ...
# 7486    Strayer University-Coral Springs Campus    Coral Springs  ...
# 7487  Strayer University-Fort Lauderdale Campus  Fort Lauderdale  ...
# 7488          Strayer University-Miramar Campus          Miramar  ...
# 7489                   Strayer University-Doral            Miami  ...
# 7490                Strayer University-Brickell            Miami  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 712            30800               20052
# 713            44100               28250
# 714              NaN   PrivacySuppressed
# 715            29400               36250
# 724            26300               20199
# ...              ...                 ...
# 7486           49200             36173.5
# 7487           49200             36173.5
# 7488           49200             36173.5
# 7489           49200             36173.5
# 7490           49200             36173.5
#
# [89 rows x 27 columns]

# %%
from IPython.display import display
for name, group in grouped:
    print(name)
    display(group.head(3))
# Out:
# ('AK', 0)
#                             INSTNM       CITY  ... MD_EARN_WNE_P10  \
# 60  University of Alaska Anchorage  Anchorage  ...           42500
# 62  University of Alaska Fairbanks  Fairbanks  ...           36200
# 63  University of Alaska Southeast     Juneau  ...           37400
#
#     GRAD_DEBT_MDN_SUPP
# 60             19449.5
# 62               19355
# 63               16875
#
# [3 rows x 27 columns]
# ('AK', 1)
#                          INSTNM       CITY  ... MD_EARN_WNE_P10  \
# 61         Alaska Bible College     Palmer  ...             NaN
# 64    Alaska Pacific University  Anchorage  ...           47000
# 5417   Alaska Christian College   Soldotna  ...             NaN
#
#       GRAD_DEBT_MDN_SUPP
# 61     PrivacySuppressed
# 64                 23250
# 5417   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('AL', 0)
#                                 INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 0             Alabama A & M University      Normal  ...           30300
# 1  University of Alabama at Birmingham  Birmingham  ...           39700
# 3  University of Alabama in Huntsville  Huntsville  ...           45500
#
#    GRAD_DEBT_MDN_SUPP
# 0               33888
# 1             21941.5
# 3               24097
#
# [3 rows x 27 columns]
# ('AL', 1)
#                          INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 2            Amridge University  Montgomery  ...           40100
# 10  Birmingham Southern College  Birmingham  ...           44200
# 12    Concordia College Alabama       Selma  ...           19900
#
#     GRAD_DEBT_MDN_SUPP
# 2                23370
# 10               27000
# 12   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('AR', 0)
#                                           INSTNM         CITY  ...  \
# 128        University of Arkansas at Little Rock  Little Rock  ...
# 129  University of Arkansas for Medical Sciences  Little Rock  ...
# 130                       ABC Beauty College Inc  Arkadelphia  ...
#
#        MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 128              33900               21736
# 129              61400               12500
# 130  PrivacySuppressed               16500
#
# [3 rows x 27 columns]
# ('AR', 1)
#                                  INSTNM         CITY  ... MD_EARN_WNE_P10  \
# 131            Arkansas Baptist College  Little Rock  ...           22000
# 134                        Lyon College   Batesville  ...           38600
# 144  Baptist Health College-Little Rock  Little Rock  ...           43200
#
#      GRAD_DEBT_MDN_SUPP
# 131               38000
# 134               25000
# 144             13393.5
#
# [3 rows x 27 columns]
# ('AS', 0)
#                                 INSTNM       CITY  ... MD_EARN_WNE_P10  \
# 4138  American Samoa Community College  Pago Pago  ...           19800
#
#       GRAD_DEBT_MDN_SUPP
# 4138   PrivacySuppressed
#
# [1 rows x 27 columns]
# ('AZ', 0)
#                                      INSTNM      CITY  ... MD_EARN_WNE_P10  \
# 69                          Collins College   Phoenix  ...           25700
# 71              Empire Beauty School-Tucson    Tucson  ...           18200
# 72  Thunderbird School of Global Management  Glendale  ...          118900
#
#     GRAD_DEBT_MDN_SUPP
# 69               47000
# 71                9833
# 72   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('AZ', 1)
#                                   INSTNM     CITY  ...    MD_EARN_WNE_P10  \
# 68               Everest College-Phoenix  Phoenix  ...              28600
# 70  Empire Beauty School-Paradise Valley  Phoenix  ...              17800
# 73           American Indian College Inc  Phoenix  ...  PrivacySuppressed
#
#     GRAD_DEBT_MDN_SUPP
# 68                9500
# 70                9588
# 73   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('CA', 0)
#                                              INSTNM            CITY  ...  \
# 192                       Academy of Art University   San Francisco  ...
# 193          ITT Technical Institute-Rancho Cordova  Rancho Cordova  ...
# 194  Academy of Chinese Culture and Health Sciences         Oakland  ...
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 192           36000               35093
# 193           38800             25827.5
# 194             NaN   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('CA', 1)
#                                     INSTNM      CITY  ...    MD_EARN_WNE_P10  \
# 200  American Baptist Seminary of the West  Berkeley  ...                NaN
# 210               Azusa Pacific University     Azusa  ...              50000
# 214                    Bethesda University   Anaheim  ...  PrivacySuppressed
#
#      GRAD_DEBT_MDN_SUPP
# 200   PrivacySuppressed
# 210               22500
# 214   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('CO', 0)
#                                             INSTNM            CITY  ...  \
# 565  The Salon Professional Academy-Grand Junction  Grand Junction  ...
# 566                         Adams State University         Alamosa  ...
# 567                         Aims Community College         Greeley  ...
#
#        MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 565  PrivacySuppressed                9570
# 566              32800               16255
# 567              31400                8773
#
# [3 rows x 27 columns]
# ('CO', 1)
#                                INSTNM         CITY  ... MD_EARN_WNE_P10  \
# 575     Colorado Christian University     Lakewood  ...           36900
# 589  Prince Institute-Rocky Mountains  Westminster  ...           33400
# 592                   Denver Seminary    Littleton  ...             NaN
#
#      GRAD_DEBT_MDN_SUPP
# 575               25808
# 589               20992
# 592   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('CT', 0)
#                                              INSTNM      CITY  ...  \
# 629                Paul Mitchell the School-Danbury   Danbury  ...
# 630                     Asnuntuck Community College   Enfield  ...
# 631  Branford Hall Career Institute-Branford Campus  Branford  ...
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 629           19000               10486
# 630           30900                5500
# 631           27900                9800
#
# [3 rows x 27 columns]
# ('CT', 1)
#                                  INSTNM       CITY  ... MD_EARN_WNE_P10  \
# 628             Albertus Magnus College  New Haven  ...           52100
# 645                Fairfield University  Fairfield  ...           68500
# 652  Holy Apostles College and Seminary   Cromwell  ...             NaN
#
#      GRAD_DEBT_MDN_SUPP
# 628             27763.5
# 645             26852.5
# 652   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('DC', 0)
#                                      INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 698  University of the District of Columbia  Washington  ...           34800
# 700                    Gallaudet University  Washington  ...           26000
# 701            George Washington University  Washington  ...           65400
#
#      GRAD_DEBT_MDN_SUPP
# 698             22393.5
# 700               17750
# 701               25350
#
# [3 rows x 27 columns]
# ('DC', 1)
#                                                 INSTNM        CITY  ...  \
# 696                                American University  Washington  ...
# 697                     Catholic University of America  Washington  ...
# 699  Pontifical Faculty of the Immaculate Conceptio...  Washington  ...
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 696           55900               24589
# 697           53900               26000
# 699             NaN   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('DE', 0)
#                                                 INSTNM        CITY  ...  \
# 685  Margaret H Rollins School of Nursing at Beebe ...       Lewes  ...
# 686                          Dawn Career Institute Inc  Wilmington  ...
# 688         Delaware Technical Community College-Terry       Dover  ...
#
#        MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 685  PrivacySuppressed   PrivacySuppressed
# 686              22400                9500
# 688              30700                8000
#
# [3 rows x 27 columns]
# ('DE', 1)
#                                                 INSTNM        CITY  ...  \
# 687         Delaware Technical Community College-Owens  Georgetown  ...
# 689  Delaware Technical Community College-Stanton/W...  Wilmington  ...
# 694                                     Wesley College       Dover  ...
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 687           28800                6750
# 689           34000                7508
# 694           41600               31000
#
# [3 rows x 27 columns]
# ('FL', 0)
#                                    INSTNM             CITY  ...  \
# 709                       Wyotech-Daytona     Ormond Beach  ...
# 710  The Art Institute of Fort Lauderdale  Fort Lauderdale  ...
# 711            Atlantic Technical College    Coconut Creek  ...
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 709           31800               11600
# 710           28800               29983
# 711           31900   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('FL', 1)
#                                     INSTNM         CITY  ... MD_EARN_WNE_P10  \
# 712         The Baptist College of Florida   Graceville  ...           30800
# 713                       Barry University        Miami  ...           44100
# 714  Gooding Institute of Nurse Anesthesia  Panama City  ...             NaN
#
#      GRAD_DEBT_MDN_SUPP
# 712               20052
# 713               28250
# 714   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('FM', 0)
#                          INSTNM     CITY  ... MD_EARN_WNE_P10  \
# 4214  College of Micronesia-FSM  Pohnpei  ...           15700
#
#       GRAD_DEBT_MDN_SUPP
# 4214   PrivacySuppressed
#
# [1 rows x 27 columns]
# ('GA', 0)
#                                          INSTNM      CITY  ...  \
# 860        Abraham Baldwin Agricultural College    Tifton  ...
# 862  Interactive College of Technology-Chamblee  Chamblee  ...
# 863    Interactive College of Technology-Morrow    Morrow  ...
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 860           32000             15085.5
# 862           21100                7376
# 863           21100                7376
#
# [3 rows x 27 columns]
# ('GA', 1)
#                                 INSTNM      CITY  ... MD_EARN_WNE_P10  \
# 785  Luther Rice University & Seminary  Lithonia  ...           39400
# 861                Agnes Scott College   Decatur  ...           38800
# 867                     Andrew College  Cuthbert  ...           27500
#
#      GRAD_DEBT_MDN_SUPP
# 785               29500
# 861               27000
# 867               12875
#
# [3 rows x 27 columns]
# ('GU', 0)
#                       INSTNM      CITY  ... MD_EARN_WNE_P10  \
# 4139  Guam Community College  Mangilao  ...           22000
# 4140      University of Guam  Mangilao  ...           29900
#
#       GRAD_DEBT_MDN_SUPP
# 4139   PrivacySuppressed
# 4140   PrivacySuppressed
#
# [2 rows x 27 columns]
# ('GU', 1)
#                           INSTNM      CITY  ...    MD_EARN_WNE_P10  \
# 5289  Pacific Islands University  Mangilao  ...  PrivacySuppressed
#
#       GRAD_DEBT_MDN_SUPP
# 5289   PrivacySuppressed
#
# [1 rows x 27 columns]
# ('HI', 0)
#                               INSTNM      CITY  ... MD_EARN_WNE_P10  \
# 951     University of Hawaii at Hilo      Hilo  ...           33500
# 952    University of Hawaii at Manoa  Honolulu  ...           43000
# 953  Hawaii Institute of Hair Design  Honolulu  ...           17300
#
#      GRAD_DEBT_MDN_SUPP
# 951               19197
# 952               19000
# 953                5868
#
# [3 rows x 27 columns]
# ('HI', 1)
#                                 INSTNM      CITY  ... MD_EARN_WNE_P10  \
# 949             Heald College-Honolulu  Honolulu  ...           35000
# 950   Chaminade University of Honolulu  Honolulu  ...           38400
# 3805   Brigham Young University-Hawaii      Laie  ...           41500
#
#       GRAD_DEBT_MDN_SUPP
# 949                11676
# 950                22000
# 3805                8291
#
# [3 rows x 27 columns]
# ('IA', 0)
#                        INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 1247            Allen College    Waterloo  ...           49100
# 1248  AIB College of Business  Des Moines  ...           37000
# 1251    Capri College-Dubuque     Dubuque  ...           19400
#
#       GRAD_DEBT_MDN_SUPP
# 1247             17090.5
# 1248             19732.5
# 1251                8477
#
# [3 rows x 27 columns]
# ('IA', 1)
#                                             INSTNM          CITY  ...  \
# 1249                        Briar Cliff University    Sioux City  ...
# 1250                        Buena Vista University    Storm Lake  ...
# 1253  American College of Hairstyling-Cedar Rapids  Cedar Rapids  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1249              38100               24000
# 1250              38300             23877.5
# 1253  PrivacySuppressed   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('ID', 0)
#                               INSTNM         CITY  ... MD_EARN_WNE_P10  \
# 965         Carrington College-Boise        Boise  ...           25000
# 967           Boise State University        Boise  ...           35600
# 968  Eastern Idaho Technical College  Idaho Falls  ...           26600
#
#      GRAD_DEBT_MDN_SUPP
# 965                9500
# 967               23500
# 968               11375
#
# [3 rows x 27 columns]
# ('ID', 1)
#                              INSTNM     CITY  ... MD_EARN_WNE_P10  \
# 966             Boise Bible College    Boise  ...           25500
# 977   Northwest Nazarene University    Nampa  ...           35900
# 979  Brigham Young University-Idaho  Rexburg  ...           38800
#
#      GRAD_DEBT_MDN_SUPP
# 966               19596
# 977               25500
# 979               11000
#
# [3 rows x 27 columns]
# ('IL', 0)
#                                              INSTNM          CITY  ...  \
# 43                       Prince Institute-Southeast      Elmhurst  ...
# 981                                Adler University       Chicago  ...
# 982  Alvareitas College of Cosmetology-Edwardsville  Edwardsville  ...
#
#        MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 43   PrivacySuppressed               20992
# 981                NaN   PrivacySuppressed
# 982  PrivacySuppressed                9911
#
# [3 rows x 27 columns]
# ('IL', 1)
#                                      INSTNM         CITY  ... MD_EARN_WNE_P10  \
# 986                       Augustana College  Rock Island  ...           47900
# 992                       Blackburn College  Carlinville  ...           37100
# 1004  Catholic Theological Union at Chicago      Chicago  ...             NaN
#
#       GRAD_DEBT_MDN_SUPP
# 986                27000
# 992                26000
# 1004   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('IN', 0)
#                                INSTNM          CITY  ...    MD_EARN_WNE_P10  \
# 1165  Apex Academy of Hair Design Inc      Anderson  ...  PrivacySuppressed
# 1166            Ball State University        Muncie  ...              38800
# 1168                Butler University  Indianapolis  ...              55000
#
#       GRAD_DEBT_MDN_SUPP
# 1165   PrivacySuppressed
# 1166               25000
# 1168               27000
#
# [3 rows x 27 columns]
# ('IN', 1)
#                             INSTNM       CITY  ... MD_EARN_WNE_P10  \
# 990   Bethany Theological Seminary   Richmond  ...             NaN
# 1163               Ancilla College  Donaldson  ...           29400
# 1164           Anderson University   Anderson  ...           35600
#
#       GRAD_DEBT_MDN_SUPP
# 990    PrivacySuppressed
# 1163               17000
# 1164               27000
#
# [3 rows x 27 columns]
# ('KS', 0)
#                                 INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 1326    Allen County Community College        Iola  ...           29100
# 1328   Barton County Community College  Great Bend  ...           32200
# 1332  Brown Mackie College-Kansas City      Lenexa  ...           25200
#
#       GRAD_DEBT_MDN_SUPP
# 1326                6900
# 1328                8976
# 1332               16000
#
# [3 rows x 27 columns]
# ('KS', 1)
#                    INSTNM          CITY  ... MD_EARN_WNE_P10  \
# 1327     Baker University  Baldwin City  ...           48800
# 1329  Benedictine College      Atchison  ...           39600
# 1330      Bethany College     Lindsborg  ...           38100
#
#       GRAD_DEBT_MDN_SUPP
# 1327               25250
# 1329               26000
# 1330               27000
#
# [3 rows x 27 columns]
# ('KY', 0)
#                                        INSTNM          CITY  ...  \
# 1389                      Alice Lloyd College  Pippa Passes  ...
# 1390                        Asbury University       Wilmore  ...
# 1392  Ashland Community and Technical College       Ashland  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1389           33500               16495
# 1390           33600               25250
# 1392           23700               11780
#
# [3 rows x 27 columns]
# ('KY', 1)
#                            INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 1391  Asbury Theological Seminary     Wilmore  ...           42500
# 1394        Bellarmine University  Louisville  ...           46600
# 1398           Brescia University   Owensboro  ...           37500
#
#       GRAD_DEBT_MDN_SUPP
# 1391   PrivacySuppressed
# 1394               25000
# 1398               30500
#
# [3 rows x 27 columns]
# ('LA', 0)
#                                              INSTNM        CITY  ...  \
# 1461  Central Louisiana Technical Community College  Alexandria  ...
# 1462                    American School of Business  Shreveport  ...
# 1463                           Ayers Career College  Shreveport  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1461  PrivacySuppressed   PrivacySuppressed
# 1462              19400                9500
# 1463              25100                9500
#
# [3 rows x 27 columns]
# ('LA', 1)
#                               INSTNM         CITY  ... MD_EARN_WNE_P10  \
# 1470  Centenary College of Louisiana   Shreveport  ...           40400
# 1478              Dillard University  New Orleans  ...           32800
# 1492               Louisiana College    Pineville  ...           39100
#
#       GRAD_DEBT_MDN_SUPP
# 1470               25000
# 1478               35000
# 1492             23743.5
#
# [3 rows x 27 columns]
# ('MA', 0)
#                                            INSTNM         CITY  ...  \
# 1619           Hult International Business School    Cambridge  ...
# 1620  New England College of Business and Finance       Boston  ...
# 1621               American International College  Springfield  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1619             NaN   PrivacySuppressed
# 1620             NaN               18450
# 1621           38900               27000
#
# [3 rows x 27 columns]
# ('MA', 1)
#                                  INSTNM           CITY  ... MD_EARN_WNE_P10  \
# 1623  Andover Newton Theological School  Newton Centre  ...             NaN
# 1624                 Anna Maria College         Paxton  ...           41900
# 1626                 Assumption College      Worcester  ...           53600
#
#       GRAD_DEBT_MDN_SUPP
# 1623   PrivacySuppressed
# 1624               25361
# 1626               27000
#
# [3 rows x 27 columns]
# ('MD', 0)
#                                    INSTNM          CITY  ...  \
# 1556            Aaron's Academy of Beauty       Waldorf  ...
# 1557  Aesthetics Institute of Cosmetology  Gaithersburg  ...
# 1558         Allegany College of Maryland    Cumberland  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1556  PrivacySuppressed   PrivacySuppressed
# 1557  PrivacySuppressed                6333
# 1558              29300               14072
#
# [3 rows x 27 columns]
# ('MD', 1)
#                                INSTNM         CITY  ... MD_EARN_WNE_P10  \
# 1570  Washington Adventist University  Takoma Park  ...           44500
# 1587       Loyola University Maryland    Baltimore  ...           63000
# 1599       Mount St Mary's University   Emmitsburg  ...           49900
#
#       GRAD_DEBT_MDN_SUPP
# 1570               27000
# 1587               27000
# 1599               25995
#
# [3 rows x 27 columns]
# ('ME', 0)
#                               INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 1526  Kaplan University-Maine Campus  S Portland  ...           33400
# 1527         College of the Atlantic  Bar Harbor  ...           26400
# 1528                   Bates College    Lewiston  ...           51600
#
#       GRAD_DEBT_MDN_SUPP
# 1526               29493
# 1527               19000
# 1528               16297
#
# [3 rows x 27 columns]
# ('ME', 1)
#                                     INSTNM      CITY  ... MD_EARN_WNE_P10  \
# 1535                     Husson University    Bangor  ...           36900
# 1549       Saint Joseph's College of Maine  Standish  ...           39100
# 4515  New England School of Communications    Bangor  ...           27400
#
#       GRAD_DEBT_MDN_SUPP
# 1535               26250
# 1549               27000
# 4515               27000
#
# [3 rows x 27 columns]
# ('MH', 0)
#                                INSTNM    CITY  ...    MD_EARN_WNE_P10  \
# 4561  College of the Marshall Islands  Majuro  ...  PrivacySuppressed
#
#       GRAD_DEBT_MDN_SUPP
# 4561   PrivacySuppressed
#
# [1 rows x 27 columns]
# ('MI', 0)
#                                              INSTNM        CITY  ...  \
# 1224  West Michigan College of Barbering and Beauty   Kalamazoo  ...
# 1755                       Hillsdale Beauty College   Hillsdale  ...
# 1756           Northwestern Technological Institute  Southfield  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1224              14800   PrivacySuppressed
# 1755  PrivacySuppressed   PrivacySuppressed
# 1756              30200                9500
#
# [3 rows x 27 columns]
# ('MI', 1)
#               INSTNM    CITY  ... MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1753  Adrian College  Adrian  ...           37100               27000
# 1754  Albion College  Albion  ...           44900               27000
# 1757    Alma College    Alma  ...           43200               27000
#
# [3 rows x 27 columns]
# ('MN', 0)
#                                         INSTNM         CITY  ...  \
# 550                          Walden University  Minneapolis  ...
# 1863                           Academy College  Bloomington  ...
# 1864  Alexandria Technical & Community College   Alexandria  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 550            59700               29125
# 1863           38500               29069
# 1864           35100               12000
#
# [3 rows x 27 columns]
# ('MN', 1)
#                         INSTNM         CITY  ... MD_EARN_WNE_P10  \
# 1868          Augsburg College  Minneapolis  ...           45700
# 1872  Bethany Lutheran College      Mankato  ...           34200
# 1873         Bethel University   Saint Paul  ...           45000
#
#       GRAD_DEBT_MDN_SUPP
# 1868               27000
# 1872               25000
# 1873               24069
#
# [3 rows x 27 columns]
# ('MO', 0)
#                                              INSTNM          CITY  ...  \
# 1357            Concorde Career College-Kansas City   Kansas City  ...
# 1999             ITT Technical Institute-Earth City    Earth City  ...
# 2001  House of Heavilin Beauty College-Blue Springs  Blue Springs  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1357           22100                9500
# 1999           38800             25827.5
# 2001           11600              9088.5
#
# [3 rows x 27 columns]
# ('MO', 1)
#                                       INSTNM         CITY  ...  \
# 1996           Aquinas Institute of Theology  Saint Louis  ...
# 1997  Assemblies of God Theological Seminary  Springfield  ...
# 1998                        Avila University  Kansas City  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1996                NaN   PrivacySuppressed
# 1997  PrivacySuppressed               22062
# 1998              41100               26625
#
# [3 rows x 27 columns]
# ('MP', 0)
#                          INSTNM    CITY  ... MD_EARN_WNE_P10  \
# 4141  Northern Marianas College  Saipan  ...           19600
#
#       GRAD_DEBT_MDN_SUPP
# 4141   PrivacySuppressed
#
# [1 rows x 27 columns]
# ('MS', 0)
#                          INSTNM          CITY  ... MD_EARN_WNE_P10  \
# 1956    Alcorn State University  Alcorn State  ...           30400
# 1959       Chris Beauty College      Gulfport  ...           15300
# 1960  Coahoma Community College    Clarksdale  ...           21100
#
#       GRAD_DEBT_MDN_SUPP
# 1956               28000
# 1959   PrivacySuppressed
# 1960   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('MS', 1)
#                                 INSTNM           CITY  ... MD_EARN_WNE_P10  \
# 1957               Belhaven University        Jackson  ...           36800
# 1958             Blue Mountain College  Blue Mountain  ...           29200
# 1963  Creations College of Cosmetology         Tupelo  ...           17900
#
#       GRAD_DEBT_MDN_SUPP
# 1957               29656
# 1958   PrivacySuppressed
# 1963   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('MT', 0)
#                                INSTNM      CITY  ...    MD_EARN_WNE_P10  \
# 2108           Academy of Cosmetology   Bozeman  ...  PrivacySuppressed
# 2109      Blackfeet Community College  Browning  ...              15600
# 2110  Butte Academy of Beauty Culture     Butte  ...  PrivacySuppressed
#
#       GRAD_DEBT_MDN_SUPP
# 2108   PrivacySuppressed
# 2109   PrivacySuppressed
# 2110                9500
#
# [3 rows x 27 columns]
# ('MT', 1)
#                          INSTNM         CITY  ... MD_EARN_WNE_P10  \
# 2113            Carroll College       Helena  ...           45500
# 2121  University of Great Falls  Great Falls  ...           30700
# 2130     Rocky Mountain College     Billings  ...           38900
#
#       GRAD_DEBT_MDN_SUPP
# 2113               27000
# 2121               24000
# 2130               25626
#
# [3 rows x 27 columns]
# ('NC', 0)
#                                 INSTNM            CITY  ... MD_EARN_WNE_P10  \
# 2642          College of the Albemarle  Elizabeth City  ...           22300
# 2643    The Art Institute of Charlotte       Charlotte  ...           28800
# 2644  South Piedmont Community College         Polkton  ...           21700
#
#       GRAD_DEBT_MDN_SUPP
# 2642   PrivacySuppressed
# 2643               25167
# 2644   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('NC', 1)
#                      INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 2647         Barton College      Wilson  ...           36000
# 2649  Belmont Abbey College     Belmont  ...           36000
# 2650        Bennett College  Greensboro  ...           26900
#
#       GRAD_DEBT_MDN_SUPP
# 2647               27000
# 2649               27000
# 2650               37000
#
# [3 rows x 27 columns]
# ('ND', 0)
#                               INSTNM       CITY  ... MD_EARN_WNE_P10  \
# 2772  Rasmussen College-North Dakota      Fargo  ...           30900
# 2773          Bismarck State College   Bismarck  ...           38400
# 2774      Dickinson State University  Dickinson  ...           38800
#
#       GRAD_DEBT_MDN_SUPP
# 2772               21163
# 2773               11588
# 2774               19500
#
# [3 rows x 27 columns]
# ('ND', 1)
#                        INSTNM       CITY  ... MD_EARN_WNE_P10  \
# 2778  University of Jamestown  Jamestown  ...           39600
# 2782       University of Mary   Bismarck  ...           45100
# 2792    Trinity Bible College  Ellendale  ...           25500
#
#       GRAD_DEBT_MDN_SUPP
# 2778               27000
# 2782               22722
# 2792               27592
#
# [3 rows x 27 columns]
# ('NE', 0)
#                                 INSTNM      CITY  ... MD_EARN_WNE_P10  \
# 2133    La'James International College   Fremont  ...           15900
# 2134               Bellevue University  Bellevue  ...           52600
# 2136  Bryan College of Health Sciences   Lincoln  ...           50900
#
#       GRAD_DEBT_MDN_SUPP
# 2133   PrivacySuppressed
# 2134               17188
# 2136             24280.5
#
# [3 rows x 27 columns]
# ('NE', 1)
#                              INSTNM    CITY  ... MD_EARN_WNE_P10  \
# 2135               Clarkson College   Omaha  ...           47000
# 2140  Concordia University-Nebraska  Seward  ...           36100
# 2141           Creighton University   Omaha  ...           57100
#
#       GRAD_DEBT_MDN_SUPP
# 2135               26000
# 2140               26000
# 2141               23250
#
# [3 rows x 27 columns]
# ('NH', 0)
#                                           INSTNM        CITY  ...  \
# 2183                        Colby-Sawyer College  New London  ...
# 2184  Continental Academie of Hair Design-Hudson      Hudson  ...
# 2185                      Daniel Webster College      Nashua  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 2183           38800               27000
# 2184           23200                9075
# 2185           50500               26999
#
# [3 rows x 27 columns]
# ('NH', 1)
#                           INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 2193  Northeast Catholic College      Warner  ...             NaN
# 2210           Rivier University      Nashua  ...           41700
# 2211        Saint Anselm College  Manchester  ...           52800
#
#       GRAD_DEBT_MDN_SUPP
# 2193   PrivacySuppressed
# 2210               25500
# 2211               27000
#
# [3 rows x 27 columns]
# ('NJ', 0)
#                                INSTNM          CITY  ... MD_EARN_WNE_P10  \
# 2215      Eastwick College-Hackensack    Hackensack  ...           27300
# 2216  Atlantic Cape Community College  Mays Landing  ...           28100
# 2217           Fortis Institute-Wayne         Wayne  ...           30400
#
#       GRAD_DEBT_MDN_SUPP
# 2215               12519
# 2216               10005
# 2217               10305
#
# [3 rows x 27 columns]
# ('NJ', 1)
#                    INSTNM          CITY  ... MD_EARN_WNE_P10  \
# 2221   Bloomfield College    Bloomfield  ...           36100
# 2224  Caldwell University      Caldwell  ...           44400
# 2226    Centenary College  Hackettstown  ...           41100
#
#       GRAD_DEBT_MDN_SUPP
# 2221               30500
# 2224               26040
# 2226             25437.5
#
# [3 rows x 27 columns]
# ('NM', 0)
#                                     INSTNM         CITY  ... MD_EARN_WNE_P10  \
# 114     Pima Medical Institute-Albuquerque  Albuquerque  ...           28200
# 2303       Olympian Academy of Cosmetology   Alamogordo  ...           17200
# 2304  Central New Mexico Community College  Albuquerque  ...           29500
#
#       GRAD_DEBT_MDN_SUPP
# 114                 8708
# 2303               11705
# 2304               10000
#
# [3 rows x 27 columns]
# ('NM', 1)
#                                  INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 7419  Computer Career Center-Las Cruces  Las Cruces  ...           21300
#
#       GRAD_DEBT_MDN_SUPP
# 7419               14250
#
# [1 rows x 27 columns]
# ('NV', 0)
#                                  INSTNM       CITY  ... MD_EARN_WNE_P10  \
# 2170   Academy of Hair Design-Las Vegas  Las Vegas  ...           17200
# 2171  Career College of Northern Nevada     Sparks  ...           23800
# 2172         College of Southern Nevada  Las Vegas  ...           31700
#
#       GRAD_DEBT_MDN_SUPP
# 2170                9500
# 2171             14020.5
# 2172               10500
#
# [3 rows x 27 columns]
# ('NV', 1)
#                                     INSTNM       CITY  ... MD_EARN_WNE_P10  \
# 6439               Touro University Nevada  Henderson  ...             NaN
# 7352  Marinello School of Beauty-Henderson  Henderson  ...           21200
#
#       GRAD_DEBT_MDN_SUPP
# 6439   PrivacySuppressed
# 7352              9796.5
#
# [2 rows x 27 columns]
# ('NY', 0)
#                                             INSTNM         CITY  ...  \
# 678               Tri-State College of Acupuncture     New York  ...
# 2334  Vaughn College of Aeronautics and Technology     Flushing  ...
# 2335                            Adelphi University  Garden City  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 678   PrivacySuppressed   PrivacySuppressed
# 2334              48700               22625
# 2335              51300               25000
#
# [3 rows x 27 columns]
# ('NY', 1)
#                           INSTNM         CITY  ... MD_EARN_WNE_P10  \
# 2375            Canisius College      Buffalo  ...           45700
# 2382    Christ the King Seminary  East Aurora  ...             NaN
# 2394  Concordia College-New York   Bronxville  ...           43200
#
#       GRAD_DEBT_MDN_SUPP
# 2375               25000
# 2382                 NaN
# 2394               26000
#
# [3 rows x 27 columns]
# ('OH', 0)
#                                                  INSTNM          CITY  ...  \
# 2796                              ETI Technical College         Niles  ...
# 2797  The Art Institute of Cincinnati-AIC College of...    Cincinnati  ...
# 2798           Miami-Jacobs Career College-Independence  Independence  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 2796           22700               13964
# 2797           29700   PrivacySuppressed
# 2798           26700               22940
#
# [3 rows x 27 columns]
# ('OH', 1)
#                           INSTNM     CITY  ...    MD_EARN_WNE_P10  \
# 2803  Allegheny Wesleyan College    Salem  ...  PrivacySuppressed
# 2808          Ashland University  Ashland  ...              39000
# 2812  Baldwin Wallace University    Berea  ...              44900
#
#       GRAD_DEBT_MDN_SUPP
# 2803   PrivacySuppressed
# 2808               27000
# 2812               27000
#
# [3 rows x 27 columns]
# ('OK', 0)
#                                           INSTNM           CITY  ...  \
# 3009  American Broadcasting School-Oklahoma City  Oklahoma City  ...
# 3013    Broken Arrow Beauty College-Broken Arrow   Broken Arrow  ...
# 3014                  Pontotoc Technology Center            Ada  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3009           27300                7023
# 3013           16800                9259
# 3014           28500   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('OK', 1)
#                             INSTNM          CITY  ... MD_EARN_WNE_P10  \
# 3010                Bacone College      Muskogee  ...           29700
# 3011  Oklahoma Wesleyan University  Bartlesville  ...           46100
# 3012  Southern Nazarene University       Bethany  ...           45800
#
#       GRAD_DEBT_MDN_SUPP
# 3010               26350
# 3011             21276.5
# 3012               18750
#
# [3 rows x 27 columns]
# ('OR', 0)
#                                  INSTNM      CITY  ...    MD_EARN_WNE_P10  \
# 3069       Academy of Hair Design-Salem     Salem  ...              14800
# 3070          Abdill Career College Inc   Medford  ...  PrivacySuppressed
# 3071  Paul Mitchell the School-Portland  Portland  ...                NaN
#
#       GRAD_DEBT_MDN_SUPP
# 3069               18519
# 3070                9500
# 3071               10194
#
# [3 rows x 27 columns]
# ('OR', 1)
#                                  INSTNM      CITY  ... MD_EARN_WNE_P10  \
# 3081      Concordia University-Portland  Portland  ...           40400
# 3086  New Hope Christian College-Eugene    Eugene  ...           26400
# 3087              George Fox University   Newberg  ...           41700
#
#       GRAD_DEBT_MDN_SUPP
# 3081               25000
# 3086               24921
# 3087               22000
#
# [3 rows x 27 columns]
# ('PA', 0)
#                                                  INSTNM          CITY  ...  \
# 3136  Abington Memorial Hospital Dixon School of Nur...  Willow Grove  ...
# 3137             Jolie Hair and Beauty Academy-Hazleton      Hazleton  ...
# 3138                       Keystone Technical Institute    Harrisburg  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3136              63300               15836
# 3137  PrivacySuppressed              8847.5
# 3138              24400             11677.5
#
# [3 rows x 27 columns]
# ('PA', 1)
#                                     INSTNM        CITY  ...  \
# 3139  Bryn Athyn College of the New Church  Bryn Athyn  ...
# 3141                      Albright College     Reading  ...
# 3144                     Allegheny College   Meadville  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3139  PrivacySuppressed             22294.5
# 3141              45800               28750
# 3144              48400               29046
#
# [3 rows x 27 columns]
# ('PR', 0)
#                                                 INSTNM     CITY  ...  \
# 4142                       Institute of Beauty Careers  Arecibo  ...
# 4143  Educational Technical College-Recinto de Bayamon  Bayamon  ...
# 4144                American University of Puerto Rico  Bayamon  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4142           12000   PrivacySuppressed
# 4143           14500   PrivacySuppressed
# 4144           19300                3920
#
# [3 rows x 27 columns]
# ('PR', 1)
#                                                  INSTNM      CITY  ...  \
# 4147             Universidad Adventista de las Antillas  Mayaguez  ...
# 4149                     Universidad Central de Bayamon   Bayamón  ...
# 4154  Pontifical Catholic University of Puerto Rico-...   Arecibo  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4147           18900               13800
# 4149           18500                8250
# 4154           17900               13195
#
# [3 rows x 27 columns]
# ('PW', 0)
#                        INSTNM   CITY  ... MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4215  Palau Community College  Koror  ...           24700   PrivacySuppressed
#
# [1 rows x 27 columns]
# ('RI', 0)
#                                      INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 3402                       Brown University  Providence  ...           59700
# 3403                      Bryant University  Smithfield  ...           64500
# 3404  Johnson & Wales University-Providence  Providence  ...           35300
#
#       GRAD_DEBT_MDN_SUPP
# 3402               15500
# 3403               27000
# 3404               27000
#
# [3 rows x 27 columns]
# ('RI', 1)
#                                INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 3401  Empire Beauty School-Providence  Providence  ...           21000
# 3408               Providence College  Providence  ...           57700
# 3414          Salve Regina University     Newport  ...           49700
#
#       GRAD_DEBT_MDN_SUPP
# 3401                9833
# 3408               27000
# 3414               27000
#
# [3 rows x 27 columns]
# ('SC', 0)
#                                    INSTNM          CITY  ...  \
# 3417              Aiken Technical College  Graniteville  ...
# 3420  Technical College of the Lowcountry      Beaufort  ...
# 3422                 Bob Jones University    Greenville  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3417              24500                9625
# 3420              25300                7500
# 3422  PrivacySuppressed               19000
#
# [3 rows x 27 columns]
# ('SC', 1)
#                               INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 3418                Allen University    Columbia  ...           21100
# 3419  Charleston Southern University  Charleston  ...           35700
# 3421                Benedict College    Columbia  ...           21400
#
#       GRAD_DEBT_MDN_SUPP
# 3418               37676
# 3419               27741
# 3421               44000
#
# [3 rows x 27 columns]
# ('SD', 0)
#                             INSTNM         CITY  ... MD_EARN_WNE_P10  \
# 3479    Black Hills Beauty College   Rapid City  ...           16200
# 3480  Black Hills State University    Spearfish  ...           34400
# 3481      Kilian Community College  Sioux Falls  ...           23100
#
#       GRAD_DEBT_MDN_SUPP
# 3479               11790
# 3480               25625
# 3481               17125
#
# [3 rows x 27 columns]
# ('SD', 1)
#                                                  INSTNM         CITY  ...  \
# 3478                               Augustana University  Sioux Falls  ...
# 3483                         Dakota Wesleyan University     Mitchell  ...
# 3486  Avera McKennan Hospital School of Radiologic T...  Sioux Falls  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3478              41800               27000
# 3483              34500               27000
# 3486  PrivacySuppressed   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('TN', 0)
#                                               INSTNM       CITY  ...  \
# 1205               ITT Technical Institute-Nashville  Nashville  ...
# 3507                           Arnolds Beauty School      Milan  ...
# 3508  Tennessee College of Applied Technology-Athens     Athens  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1205           38800             25827.5
# 3507           16000   PrivacySuppressed
# 3508           26600   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('TN', 1)
#                                            INSTNM       CITY  ...  \
# 3506                     American Baptist College  Nashville  ...
# 3510  Baptist Memorial College of Health Sciences    Memphis  ...
# 3511                           Belmont University  Nashville  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3506  PrivacySuppressed               25000
# 3510              54100               30000
# 3511              41800               22707
#
# [3 rows x 27 columns]
# ('TX', 0)
#                        INSTNM      CITY  ... MD_EARN_WNE_P10  \
# 3611  Alvin Community College     Alvin  ...           34500
# 3612         Amarillo College  Amarillo  ...           31700
# 3613         Angelina College    Lufkin  ...           26900
#
#       GRAD_DEBT_MDN_SUPP
# 3611                6750
# 3612               10950
# 3613   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('TX', 1)
#                             INSTNM       CITY  ... MD_EARN_WNE_P10  \
# 3610  Abilene Christian University    Abilene  ...           40200
# 3615     Arlington Baptist College  Arlington  ...           34200
# 3618                Austin College    Sherman  ...           47800
#
#       GRAD_DEBT_MDN_SUPP
# 3610               25985
# 3615               22905
# 3618               26000
#
# [3 rows x 27 columns]
# ('UT', 0)
#                                       INSTNM         CITY  ...  \
# 3802                 AmeriTech College-Provo        Provo  ...
# 3803  Bridgerland Applied Technology College        Logan  ...
# 3806        Broadview University-West Jordan  West Jordan  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3802           24700               24370
# 3803           24300   PrivacySuppressed
# 3806           25500               28458
#
# [3 rows x 27 columns]
# ('UT', 1)
#                                   INSTNM              CITY  ...  \
# 3804      Brigham Young University-Provo             Provo  ...
# 3817  Latter-day Saints Business College    Salt Lake City  ...
# 3818      Everest College-Salt Lake City  West Valley City  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3804           57200               11000
# 3817           35100                5799
# 3818           24400             10632.5
#
# [3 rows x 27 columns]
# ('VA', 0)
#                                 INSTNM            CITY  ... MD_EARN_WNE_P10  \
# 704                  Medtech Institute    Falls Church  ...           26300
# 3850  Bar Palma Beauty Careers Academy         Roanoke  ...           16900
# 3851     Advanced Technology Institute  Virginia Beach  ...           38000
#
#       GRAD_DEBT_MDN_SUPP
# 704                 9236
# 3850                9731
# 3851               16279
#
# [3 rows x 27 columns]
# ('VA', 1)
#                    INSTNM         CITY  ... MD_EARN_WNE_P10  \
# 3852   Averett University     Danville  ...           42400
# 3853    Bluefield College    Bluefield  ...           40000
# 3854  Bridgewater College  Bridgewater  ...           40800
#
#       GRAD_DEBT_MDN_SUPP
# 3852               25000
# 3853               18873
# 3854               27000
#
# [3 rows x 27 columns]
# ('VI', 0)
#                                 INSTNM              CITY  ... MD_EARN_WNE_P10  \
# 4216  University of the Virgin Islands  Charlotte Amalie  ...           31800
#
#       GRAD_DEBT_MDN_SUPP
# 4216               15150
#
# [1 rows x 27 columns]
# ('VI', 1)
#                                                 INSTNM       CITY  ...  \
# 7404  University of the Virgin Islands-Albert A. Sheen  St. Croix  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 7404           31800               15150
#
# [1 rows x 27 columns]
# ('VT', 0)
#                     INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 3829    Bennington College  Bennington  ...           24600
# 3830    Burlington College  Burlington  ...           26000
# 3831  Castleton University   Castleton  ...           34900
#
#       GRAD_DEBT_MDN_SUPP
# 3829               27000
# 3830               25000
# 3831               25000
#
# [3 rows x 27 columns]
# ('VT', 1)
#                        INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 3835   Green Mountain College    Poultney  ...           30100
# 3843  Saint Michael's College  Colchester  ...           46600
# 3845     College of St Joseph     Rutland  ...           34700
#
#       GRAD_DEBT_MDN_SUPP
# 3835               25449
# 3843               27400
# 3845               24127
#
# [3 rows x 27 columns]
# ('WA', 0)
#                                             INSTNM       CITY  ...  \
# 3943                                Beauty Academy  Wenatchee  ...
# 3944                  The Art Institute of Seattle    Seattle  ...
# 3945  Evergreen Beauty and Barber College-Bellevue   Bellevue  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3943  PrivacySuppressed              8718.5
# 3944              34100             25937.5
# 3945  PrivacySuppressed                7917
#
# [3 rows x 27 columns]
# ('WA', 1)
#                         INSTNM      CITY  ... MD_EARN_WNE_P10  \
# 3967        Gonzaga University   Spokane  ...           53000
# 3981  Trinity Lutheran College   Everett  ...           37100
# 3985      Northwest University  Kirkland  ...           37700
#
#       GRAD_DEBT_MDN_SUPP
# 3967               25500
# 3981               25000
# 3985             23724.5
#
# [3 rows x 27 columns]
# ('WI', 0)
#                                           INSTNM        CITY  ...  \
# 4063  Advanced Institute of Hair Design-Glendale    Glendale  ...
# 4064                        VICI Aveda Institute  Greenfield  ...
# 4066              Madison Area Technical College     Madison  ...
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4063           24000               10314
# 4064           24000               10314
# 4066           35000               14250
#
# [3 rows x 27 columns]
# ('WI', 1)
#                            INSTNM       CITY  ... MD_EARN_WNE_P10  \
# 4065              Alverno College  Milwaukee  ...           37100
# 4070  Cardinal Stritch University  Milwaukee  ...           48500
# 4071           Carroll University   Waukesha  ...           41300
#
#       GRAD_DEBT_MDN_SUPP
# 4065             32606.5
# 4070               27000
# 4071               27000
#
# [3 rows x 27 columns]
# ('WV', 0)
#                                      INSTNM       CITY  ...  \
# 2842           Scott College of Cosmetology   Wheeling  ...
# 4019  B M Spurr School of Practical Nursing  Glen Dale  ...
# 4020             Ben Franklin Career Center     Dunbar  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 2842              14800                9250
# 4019  PrivacySuppressed   PrivacySuppressed
# 4020              20800   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('WV', 1)
#                             INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 4016  Alderson Broaddus University    Philippi  ...           46000
# 4018     Appalachian Bible College  Mount Hope  ...           28700
# 4027        Davis & Elkins College      Elkins  ...           35000
#
#       GRAD_DEBT_MDN_SUPP
# 4016               27000
# 4018                9300
# 4027             23840.5
#
# [3 rows x 27 columns]
# ('WY', 0)
#                        INSTNM        CITY  ... MD_EARN_WNE_P10  \
# 4128           Casper College      Casper  ...           34800
# 4129  Central Wyoming College    Riverton  ...           25200
# 4130  Eastern Wyoming College  Torrington  ...           25900
#
#       GRAD_DEBT_MDN_SUPP
# 4128               10764
# 4129                8757
# 4130               10000
#
# [3 rows x 27 columns]

# %%
for name, group in grouped:
    print(name)
    display(group)
    break
# Out:
# ('AK', 0)
#                                       INSTNM       CITY  ... MD_EARN_WNE_P10  \
# 60            University of Alaska Anchorage  Anchorage  ...           42500
# 62            University of Alaska Fairbanks  Fairbanks  ...           36200
# 63            University of Alaska Southeast     Juneau  ...           37400
# 65    AVTEC-Alaska's Institute of Technology     Seward  ...           33500
# 66                 Charter College-Anchorage  Anchorage  ...           39200
# 67                     Alaska Career College  Anchorage  ...           28700
# 5171                       Ilisagvik College     Barrow  ...           24900
#
#       GRAD_DEBT_MDN_SUPP
# 60               19449.5
# 62                 19355
# 63                 16875
# 65     PrivacySuppressed
# 66                 13875
# 67                  8994
# 5171   PrivacySuppressed
#
# [7 rows x 27 columns]

# %%
grouped.head(1)
# Out:
#                                                 INSTNM        CITY  ...  \
# 0                             Alabama A & M University      Normal  ...
# 2                                   Amridge University  Montgomery  ...
# 43                          Prince Institute-Southeast    Elmhurst  ...
# 60                      University of Alaska Anchorage   Anchorage  ...
# 61                                Alaska Bible College      Palmer  ...
# ...                                                ...         ...  ...
# 4561                   College of the Marshall Islands      Majuro  ...
# 5289                        Pacific Islands University    Mangilao  ...
# 6439                           Touro University Nevada   Henderson  ...
# 7404  University of the Virgin Islands-Albert A. Sheen   St. Croix  ...
# 7419                 Computer Career Center-Las Cruces  Las Cruces  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0                 30300               33888
# 2                 40100               23370
# 43    PrivacySuppressed               20992
# 60                42500             19449.5
# 61                  NaN   PrivacySuppressed
# ...                 ...                 ...
# 4561  PrivacySuppressed   PrivacySuppressed
# 5289  PrivacySuppressed   PrivacySuppressed
# 6439                NaN   PrivacySuppressed
# 7404              31800               15150
# 7419              21300               14250
#
# [112 rows x 27 columns]

# %%
grouped.nth([1, -1])
# Out:
#                                                      INSTNM  \
# STABBR RELAFFIL
# AK     0                     University of Alaska Fairbanks
#        0                                  Ilisagvik College
#        1                          Alaska Pacific University
#        1                           Alaska Christian College
# AL     0                University of Alabama at Birmingham
# ...                                                     ...
# WV     0         BridgeValley Community & Technical College
#        1                          Appalachian Bible College
#        1         West Virginia Business College-Nutter Fort
# WY     0                            Central Wyoming College
#        0                            CollegeAmerica-Cheyenne
#
#                               CITY  ...  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# STABBR RELAFFIL                     ...
# AK     0                 Fairbanks  ...            36200               19355
#        0                    Barrow  ...            24900   PrivacySuppressed
#        1                 Anchorage  ...            47000               23250
#        1                  Soldotna  ...              NaN   PrivacySuppressed
# AL     0                Birmingham  ...            39700             21941.5
# ...                            ...  ...              ...                 ...
# WV     0         South  Charleston  ...              NaN              9429.5
#        1                Mount Hope  ...            28700                9300
#        1               Nutter Fort  ...            16700               19258
# WY     0                  Riverton  ...            25200                8757
#        0                  Cheyenne  ...            25600             27235.5
#
# [213 rows x 25 columns]

# %% [markdown]
# ## 9.7 過濾特定的組別

# %%
college = pd.read_csv('data/college.csv', index_col='INSTNM')
grouped = college.groupby('STABBR')
grouped.ngroups
# Out:
# 59

# %%
college['STABBR'].nunique()
# Out:
# 59

# %%
def check_minority(df, threshold):
    minority_pct = 1 - df['UGDS_WHITE']
    total_minority = (df['UGDS'] * minority_pct).sum()
    total_ugds = df['UGDS'].sum()
    total_minority_pct = total_minority / total_ugds
    return total_minority_pct > threshold

# %%
college_filtered = grouped.filter(check_minority, threshold=.5)
college_filtered
# Out:
#                                                            CITY STABBR  ...  \
# INSTNM                                                                  ...
# Everest College-Phoenix                                 Phoenix     AZ  ...
# Collins College                                         Phoenix     AZ  ...
# Empire Beauty School-Paradise Valley                    Phoenix     AZ  ...
# Empire Beauty School-Tucson                              Tucson     AZ  ...
# Thunderbird School of Global Management                Glendale     AZ  ...
# ...                                                         ...    ...  ...
# WestMed College - Merced                                 Merced     CA  ...
# Vantage College                                         El Paso     TX  ...
# SAE Institute of Technology  San Francisco           Emeryville     CA  ...
# Bay Area Medical Academy - San Jose Satellite L...     San Jose     CA  ...
# Excel Learning Center-San Antonio South             San Antonio     TX  ...
#
#                                                     MD_EARN_WNE_P10  \
# INSTNM
# Everest College-Phoenix                                       28600
# Collins College                                               25700
# Empire Beauty School-Paradise Valley                          17800
# Empire Beauty School-Tucson                                   18200
# Thunderbird School of Global Management                      118900
# ...                                                             ...
# WestMed College - Merced                                        NaN
# Vantage College                                                 NaN
# SAE Institute of Technology  San Francisco                      NaN
# Bay Area Medical Academy - San Jose Satellite L...              NaN
# Excel Learning Center-San Antonio South                         NaN
#
#                                                     GRAD_DEBT_MDN_SUPP
# INSTNM
# Everest College-Phoenix                                           9500
# Collins College                                                  47000
# Empire Beauty School-Paradise Valley                              9588
# Empire Beauty School-Tucson                                       9833
# Thunderbird School of Global Management              PrivacySuppressed
# ...                                                                ...
# WestMed College - Merced                                       15623.5
# Vantage College                                                   9500
# SAE Institute of Technology  San Francisco                        9500
# Bay Area Medical Academy - San Jose Satellite L...   PrivacySuppressed
# Excel Learning Center-San Antonio South                          12125
#
# [3028 rows x 26 columns]

# %%
college.shape
# Out:
# (7535, 26)

# %%
college_filtered.shape
# Out:
# (3028, 26)

# %%
college_filtered['STABBR'].nunique()
# Out:
# 20

# %%
college_filtered_20 = grouped.filter(check_minority, threshold=.2)
college_filtered_20.shape
# Out:
# (7461, 26)

# %%
college_filtered_20['STABBR'].nunique()
# Out:
# 57

# %%
college_filtered_70 = grouped.filter(check_minority, threshold=.7)
college_filtered_70.shape
# Out:
# (957, 26)

# %%
college_filtered_70['STABBR'].nunique()
# Out:
# 10

# %% [markdown]
# ## 9.8 分組轉換特定欄位的資料

# %%
weight_loss = pd.read_csv('data/weight_loss.csv')
weight_loss.query('Month == "Jan"')
# Out:
#   Name Month    Week  Weight
# 0  Bob   Jan  Week 1     291
# 1  Amy   Jan  Week 1     197
# 2  Bob   Jan  Week 2     288
# 3  Amy   Jan  Week 2     189
# 4  Bob   Jan  Week 3     283
# 5  Amy   Jan  Week 3     189
# 6  Bob   Jan  Week 4     283
# 7  Amy   Jan  Week 4     190

# %%
def percent_loss(s):
    return ((s - s.iloc[0]) / s.iloc[0]) * 100

# %%
(weight_loss
    .query('Name=="Bob" and Month=="Jan"')
    ['Weight']
    .pipe(percent_loss)
)
# Out:
# 0    0.000000
# 2   -1.030928
# 4   -2.749141
# 6   -2.749141
# Name: Weight, dtype: float64

# %%
(weight_loss
    .groupby(['Name', 'Month'])
    ['Weight'] 
    .transform(percent_loss)
)
# Out:
# 0     0.000000
# 1     0.000000
# 2    -1.030928
# 3    -4.060914
# 4    -2.749141
#         ...
# 27   -3.529412
# 28   -3.065134
# 29   -3.529412
# 30   -4.214559
# 31   -5.294118
# Name: Weight, Length: 32, dtype: float64

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Name=="Bob" and Month in ["Jan", "Feb"]')
)
# Out:
#    Name Month  ... Weight  percent_loss
# 0   Bob   Jan  ...    291           0.0
# 2   Bob   Jan  ...    288          -1.0
# 4   Bob   Jan  ...    283          -2.7
# 6   Bob   Jan  ...    283          -2.7
# 8   Bob   Feb  ...    283           0.0
# 10  Bob   Feb  ...    275          -2.8
# 12  Bob   Feb  ...    268          -5.3
# 14  Bob   Feb  ...    268          -5.3
#
# [8 rows x 5 columns]

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
)
# Out:
#    Name Month  ... Weight  percent_loss
# 6   Bob   Jan  ...    283          -2.7
# 7   Amy   Jan  ...    190          -3.6
# 14  Bob   Feb  ...    268          -5.3
# 15  Amy   Feb  ...    173          -8.9
# 22  Bob   Mar  ...    261          -2.6
# 23  Amy   Mar  ...    170          -1.7
# 30  Bob   Apr  ...    250          -4.2
# 31  Amy   Apr  ...    161          -5.3
#
# [8 rows x 5 columns]

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss')
)
# Out:
# Name   Amy  Bob
# Month
# Apr   -5.3 -4.2
# Feb   -8.9 -5.3
# Jan   -3.6 -2.7
# Mar   -1.7 -2.6

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss')
    .assign(winner=lambda df_:
            np.where(df_.Amy < df_.Bob, 'Amy', 'Bob'))
)
# Out:
# Name   Amy  Bob winner
# Month
# Apr   -5.3 -4.2    Amy
# Feb   -8.9 -5.3    Amy
# Jan   -3.6 -2.7    Amy
# Mar   -1.7 -2.6    Bob

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss')
    .assign(winner=lambda df_:
            np.where(df_.Amy < df_.Bob, 'Amy', 'Bob'))
    .style.highlight_min(axis=1,color='lightgrey')
)
# Out:
# <style  type="text/css" >
#     #T_ce7eb106_428d_11ec_9423_74c63be20db0row0_col0 {
#             background-color:  lightgrey;
#         }    #T_ce7eb106_428d_11ec_9423_74c63be20db0row1_col0 {
#             background-color:  lightgrey;
#         }    #T_ce7eb106_428d_11ec_9423_74c63be20db0row2_col0 {
#             background-color:  lightgrey;
#         }    #T_ce7eb106_428d_11ec_9423_74c63be20db0row3_col1 {
#             background-color:  lightgrey;
#         }</style><table id="T_ce7eb106_428d_11ec_9423_74c63be20db0" ><thead>    <tr>        <th class="index_name level0" >Name</th>        <th class="col_heading level0 col0" >Amy</th>        <th class="col_heading level0 col1" >Bob</th>        <th class="col_heading level0 col2" >winner</th>    </tr>    <tr>        <th class="index_name level0" >Month</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ce7eb106_428d_11ec_9423_74c63be20db0level0_row0" class="row_heading level0 row0" >Apr</th>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row0_col0" class="data row0 col0" >-5.300000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row0_col1" class="data row0 col1" >-4.200000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row0_col2" class="data row0 col2" >Amy</td>
#             </tr>
#             <tr>
#                         <th id="T_ce7eb106_428d_11ec_9423_74c63be20db0level0_row1" class="row_heading level0 row1" >Feb</th>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row1_col0" class="data row1 col0" >-8.900000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row1_col1" class="data row1 col1" >-5.300000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row1_col2" class="data row1 col2" >Amy</td>
#             </tr>
#             <tr>
#                         <th id="T_ce7eb106_428d_11ec_9423_74c63be20db0level0_row2" class="row_heading level0 row2" >Jan</th>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row2_col0" class="data row2 col0" >-3.600000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row2_col1" class="data row2 col1" >-2.700000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row2_col2" class="data row2 col2" >Amy</td>
#             </tr>
#             <tr>
#                         <th id="T_ce7eb106_428d_11ec_9423_74c63be20db0level0_row3" class="row_heading level0 row3" >Mar</th>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row3_col0" class="data row3 col0" >-1.700000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row3_col1" class="data row3 col1" >-2.600000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row3_col2" class="data row3 col2" >Bob</td>
#             </tr>
#     </tbody></table>

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss')
    .assign(winner=lambda df_:
            np.where(df_.Amy < df_.Bob, 'Amy', 'Bob'))
    .winner
    .value_counts()
)
# Out:
# Amy    3
# Bob    1
# Name: winner, dtype: int64

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)),
            Month=pd.Categorical(weight_loss.Month,
                  categories=['Jan', 'Feb', 'Mar', 'Apr'],
                  ordered=True))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss')
)
# Out:
# Name   Amy  Bob
# Month
# Jan   -3.6 -2.7
# Feb   -8.9 -5.3
# Mar   -1.7 -2.6
# Apr   -5.3 -4.2

# %% [markdown]
# ## 9.9 使用apply()計算加權平均數

# %%
college = pd.read_csv('data/college.csv')
subset = ['UGDS', 'SATMTMID', 'SATVRMID']
college2 = college.dropna(subset=subset)
college.shape
# Out:
# (7535, 27)

# %%
college2.shape
# Out:
# (1184, 27)

# %%
def weighted_math_average(df):
    weighted_math = df['UGDS'] * df['SATMTMID']
    return int(weighted_math.sum() / df['UGDS'].sum())

# %%
college2.groupby('STABBR').apply(weighted_math_average)
# Out:
# STABBR
# AK    503
# AL    536
# AR    529
# AZ    569
# CA    564
#      ...
# VT    566
# WA    555
# WI    593
# WV    500
# WY    540
# Length: 53, dtype: int64

# %%
# (college2
#     .groupby('STABBR')
#     .agg(weighted_math_average)
# )

# %%
# (college2
#     .groupby('STABBR')
#     ['SATMTMID'] 
#     .agg(weighted_math_average)
# )

# %%
def weighted_average(df):
    weight_m = df['UGDS'] * df['SATMTMID']
    weight_v = df['UGDS'] * df['SATVRMID']
    wm_avg = weight_m.sum() / df['UGDS'].sum()
    wv_avg = weight_v.sum() / df['UGDS'].sum()
    data = {'w_math_avg': wm_avg,
            'w_verbal_avg': wv_avg,
            'math_avg': df['SATMTMID'].mean(),
            'verbal_avg': df['SATVRMID'].mean(),
            'count': len(df)
    }
    return pd.Series(data)

# %%
weighted_average(college2)
# Out:
# w_math_avg       559.408812
# w_verbal_avg     542.989462
# math_avg         530.958615
# verbal_avg       522.775338
# count           1184.000000
# dtype: float64

# %%
(college2
    .groupby('STABBR')
    .apply(weighted_average)
    .astype(int)
)
# Out:
#         w_math_avg  w_verbal_avg  ...  verbal_avg  count
# STABBR                            ...
# AK             503           555  ...         555      1
# AL             536           533  ...         508     21
# AR             529           504  ...         491     16
# AZ             569           557  ...         538      6
# CA             564           539  ...         549     72
# ...            ...           ...  ...         ...    ...
# VT             566           564  ...         527      8
# WA             555           541  ...         548     18
# WI             593           556  ...         516     14
# WV             500           487  ...         473     17
# WY             540           535  ...         535      1
#
# [53 rows x 5 columns]

# %%
from scipy.stats import gmean, hmean
def calculate_means(df):
    df_means = pd.DataFrame(index=['Arithmetic', 'Weighted',
                                   'Geometric', 'Harmonic'])
    cols = ['SATMTMID', 'SATVRMID']
    for col in cols:
        arithmetic = df[col].mean()
        weighted = np.average(df[col], weights=df['UGDS'])
        geometric = gmean(df[col])
        harmonic = hmean(df[col])
        df_means[col] = [arithmetic, weighted,
                         geometric, harmonic]
    df_means['count'] = len(df)
    return df_means.astype(int)
(college2
    .groupby('STABBR')
    .apply(calculate_means)
)
# Out:
#                    SATMTMID  SATVRMID  count
# STABBR
# AK     Arithmetic       503       555      1
#        Weighted         503       555      1
#        Geometric        503       555      1
#        Harmonic         503       555      1
# AL     Arithmetic       504       508     21
# ...                     ...       ...    ...
# WV     Harmonic         480       472     17
# WY     Arithmetic       540       535      1
#        Weighted         540       535      1
#        Geometric        540       534      1
#        Harmonic         540       535      1
#
# [212 rows x 3 columns]

# %% [markdown]
# ## 9.10 以連續變化的數值進行分組

# %%
flights = pd.read_csv('data/flights.csv')
flights
# Out:
#        MONTH  DAY  ...  DIVERTED CANCELLED
# 0          1    1  ...         0         0
# 1          1    1  ...         0         0
# 2          1    1  ...         0         0
# 3          1    1  ...         0         0
# 4          1    1  ...         0         0
# ...      ...  ...  ...       ...       ...
# 58487     12   31  ...         0         0
# 58488     12   31  ...         0         0
# 58489     12   31  ...         0         0
# 58490     12   31  ...         0         0
# 58491     12   31  ...         0         0
#
# [58492 rows x 14 columns]

# %%
bins = [-np.inf, 200, 500, 1000, 2000, np.inf]
cuts = pd.cut(flights['DIST'], bins=bins)
cuts
# Out:
# 0         (500.0, 1000.0]
# 1        (1000.0, 2000.0]
# 2         (500.0, 1000.0]
# 3        (1000.0, 2000.0]
# 4        (1000.0, 2000.0]
#                ...
# 58487    (1000.0, 2000.0]
# 58488      (200.0, 500.0]
# 58489      (200.0, 500.0]
# 58490     (500.0, 1000.0]
# 58491     (500.0, 1000.0]
# Name: DIST, Length: 58492, dtype: category
# Categories (5, interval[float64]): [(-inf, 200.0] < (200.0, 500.0] < (500.0, 1000.0] < (1000.0, 2000.0] < (2000.0, inf]]

# %%
cuts.value_counts()
# Out:
# (500.0, 1000.0]     20659
# (200.0, 500.0]      15874
# (1000.0, 2000.0]    14186
# (2000.0, inf]        4054
# (-inf, 200.0]        3719
# Name: DIST, dtype: int64

# %%
(flights
    .groupby(cuts)
    ['AIRLINE']
    .value_counts(normalize=True) 
    .round(3)
)
# Out:
# DIST           AIRLINE
# (-inf, 200.0]  OO         0.326
#                EV         0.289
#                MQ         0.211
#                DL         0.086
#                AA         0.052
#                           ...
# (2000.0, inf]  WN         0.046
#                HA         0.028
#                NK         0.019
#                AS         0.012
#                F9         0.004
# Name: AIRLINE, Length: 57, dtype: float64

# %%
(flights
  .groupby(cuts)
  ['AIR_TIME']
  .quantile(q=[.25, .5, .75]) 
  .div(60)
  .round(2)
)
# Out:
# DIST
# (-inf, 200.0]     0.25    0.43
#                   0.50    0.50
#                   0.75    0.57
# (200.0, 500.0]    0.25    0.77
#                   0.50    0.92
#                           ...
# (1000.0, 2000.0]  0.50    2.93
#                   0.75    3.40
# (2000.0, inf]     0.25    4.30
#                   0.50    4.70
#                   0.75    5.03
# Name: AIR_TIME, Length: 15, dtype: float64

# %% [markdown]
# ## 9.11 案例演練：計算城市之間的航班總數

# %%
flights = pd.read_csv('data/flights.csv')
flights_ct = flights.groupby(['ORG_AIR', 'DEST_AIR']).size()
flights_ct
# Out:
# ORG_AIR  DEST_AIR
# ATL      ABE          31
#          ABQ          16
#          ABY          19
#          ACY           6
#          AEX          40
#                     ...
# SFO      SNA         122
#          STL          20
#          SUN          10
#          TUS          20
#          XNA           2
# Length: 1130, dtype: int64

# %%
flights_ct.loc[[('ATL', 'IAH'), ('IAH', 'ATL')]]
# Out:
# ORG_AIR  DEST_AIR
# ATL      IAH         121
# IAH      ATL         148
# dtype: int64

# %%
f_part3 = (flights  
  [['ORG_AIR', 'DEST_AIR']] 
  .apply(lambda ser:
         ser.sort_values().reset_index(drop=True),
         axis='columns')
)
f_part3
# Out:
#          0    1
# 0      LAX  SLC
# 1      DEN  IAD
# 2      DFW  VPS
# 3      DCA  DFW
# 4      LAX  MCI
# ...    ...  ...
# 58487  DFW  SFO
# 58488  LAS  SFO
# 58489  SBA  SFO
# 58490  ATL  MSP
# 58491  BOI  SFO
#
# [58492 rows x 2 columns]

# %%
rename_dict = {0:'AIR1', 1:'AIR2'}  
(flights    
  [['ORG_AIR', 'DEST_AIR']]
  .apply(lambda ser:
         ser.sort_values().reset_index(drop=True),
         axis='columns')
  .rename(columns=rename_dict)
  .groupby(['AIR1', 'AIR2'])
  .size()
)
# Out:
# AIR1  AIR2
# ABE   ATL      31
#       ORD      24
# ABI   DFW      74
# ABQ   ATL      16
#       DEN      46
#              ...
# SFO   SNA     122
#       STL      20
#       SUN      10
#       TUS      20
#       XNA       2
# Length: 1085, dtype: int64

# %%
(flights     
  [['ORG_AIR', 'DEST_AIR']]
  .apply(lambda ser:
         ser.sort_values().reset_index(drop=True),
         axis='columns')
  .rename(columns=rename_dict)
  .groupby(['AIR1', 'AIR2'])
  .size()
  .loc[('ATL', 'IAH')]
)
# Out:
# 269

# %%
# (flights     
#   [['ORG_AIR', 'DEST_AIR']]
#   .apply(lambda ser:
#          ser.sort_values().reset_index(drop=True),
#          axis='columns')
#   .rename(columns=rename_dict)
#   .groupby(['AIR1', 'AIR2'])
#   .size()
#   .loc[('IAH', 'ATL')]
# )

# %%
data_sorted = np.sort(flights[['ORG_AIR', 'DEST_AIR']])
data_sorted[:10]
# Out:
# array([['LAX', 'SLC'],
#        ['DEN', 'IAD'],
#        ['DFW', 'VPS'],
#        ['DCA', 'DFW'],
#        ['LAX', 'MCI'],
#        ['IAH', 'SAN'],
#        ['DFW', 'MSY'],
#        ['PHX', 'SFO'],
#        ['ORD', 'STL'],
#        ['IAH', 'SJC']], dtype=object)

# %%
flights_sort2 = pd.DataFrame(data_sorted, columns=['AIR1', 'AIR2'])
flights_sort2.equals(f_part3.rename(columns={0:'AIR1', 1:'AIR2'}))
# Out:
# True

# %%
# %%timeit
flights_sort = (flights   # doctest: +SKIP
    [['ORG_AIR', 'DEST_AIR']] 
   .apply(lambda ser:
         ser.sort_values().reset_index(drop=True),
         axis='columns')
)
# Out:
# 50.8 s ± 4.86 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
data_sorted = np.sort(flights[['ORG_AIR', 'DEST_AIR']])
flights_sort2 = pd.DataFrame(data_sorted, columns=['AIR1', 'AIR2'])
# Out:
# 13.2 ms ± 911 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## 9.12 案例演練：尋找航班的連續準時記錄

# %%
s = pd.Series([0, 1, 1, 0, 1, 1, 1, 0])
s
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# 5    1
# 6    1
# 7    0
# dtype: int64

# %%
s1 = s.cumsum()
s1
# Out:
# 0    0
# 1    1
# 2    2
# 3    2
# 4    3
# 5    4
# 6    5
# 7    5
# dtype: int64

# %%
s.mul(s1)
# Out:
# 0    0
# 1    1
# 2    2
# 3    0
# 4    3
# 5    4
# 6    5
# 7    0
# dtype: int64

# %%
s.mul(s1).diff()
# Out:
# 0    NaN
# 1    1.0
# 2    1.0
# 3   -2.0
# 4    3.0
# 5    1.0
# 6    1.0
# 7   -5.0
# dtype: float64

# %%
(s.mul(s.cumsum())
  .diff()
  .where(lambda x: x < 0))
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3   -2.0
# 4    NaN
# 5    NaN
# 6    NaN
# 7   -5.0
# dtype: float64

# %%
(s.mul(s.cumsum())
  .diff()
  .where(lambda x: x < 0)
  .ffill())
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3   -2.0
# 4   -2.0
# 5   -2.0
# 6   -2.0
# 7   -5.0
# dtype: float64

# %%
(s.mul(s.cumsum())
  .diff()
  .where(lambda x: x < 0)
  .ffill()
  .add(s.cumsum(), fill_value=0))
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# 3    0.0
# 4    1.0
# 5    2.0
# 6    3.0
# 7    0.0
# dtype: float64

# %%
flights = pd.read_csv('data/flights.csv')
(flights.assign(ON_TIME=flights['ARR_DELAY'].lt(15).astype(int))
        [['AIRLINE', 'ORG_AIR', 'ON_TIME']])
# Out:
#       AIRLINE ORG_AIR  ON_TIME
# 0          WN     LAX        0
# 1          UA     DEN        1
# 2          MQ     DFW        0
# 3          AA     DFW        1
# 4          WN     LAX        0
# ...       ...     ...      ...
# 58487      AA     SFO        1
# 58488      F9     LAS        1
# 58489      OO     SFO        1
# 58490      WN     MSP        0
# 58491      OO     SFO        1
#
# [58492 rows x 3 columns]

# %%
def max_streak(s):
    s1 = s.cumsum()
    return (s.mul(s1)
             .diff()
             .where(lambda x: x < 0) 
             .ffill()
             .add(s1, fill_value=0)
             .max())

# %%
(flights
    .assign(ON_TIME=flights['ARR_DELAY'].lt(15).astype(int))
    .sort_values(['MONTH', 'DAY', 'SCHED_DEP']) 
    .groupby(['AIRLINE', 'ORG_AIR'])
    ['ON_TIME'] 
    .agg(['mean', 'size', max_streak])
    .round(2)
)
# Out:
#                  mean  size  max_streak
# AIRLINE ORG_AIR
# AA      ATL      0.82   233          15
#         DEN      0.74   219          17
#         DFW      0.78  4006          64
#         IAH      0.80   196          24
#         LAS      0.79   374          29
# ...               ...   ...         ...
# WN      LAS      0.77  2031          39
#         LAX      0.70  1135          23
#         MSP      0.84   237          32
#         PHX      0.77  1724          33
#         SFO      0.76   445          17
#
# [114 rows x 3 columns]
