# %%
import csv
import pandas as pd

df = pd.read_csv('data/aqx_p_488.csv')

# %%
df
# Out:
#      sitename county  aqi pollutant status  so2    co    o3  o3_8hr  pm10  \
# 0      屏東(枋山)    屏東縣   19       NaN     良好  0.3  0.03  23.9    21.4  16.0
# 1    大甲（日南國小）    臺中市   20       NaN     良好  0.3  0.15  21.2    22.4  10.0
# 2      新北(樹林)    新北市   40       NaN     良好  0.7  0.15  31.3    22.4  29.0
# 3      屏東（琉球）    屏東縣   27       NaN     良好  NaN  0.07  14.3    12.8  14.0
# 4      臺南（麻豆）    臺南市   20       NaN     良好  0.6  0.09  16.2    19.4  15.0
# ..        ...    ...  ...       ...    ...  ...   ...   ...     ...   ...
# 995        頭份    苗栗縣   12       NaN     良好  1.8  0.14   8.2    10.5  10.0
# 996        新竹    新竹市   12       NaN     良好  0.4  0.12   7.1     6.7   3.0
# 997        竹東    新竹縣   19       NaN     良好  0.2  0.10   1.2     3.3  17.0
# 998        湖口    新竹縣   32       NaN     良好  0.0  0.13   9.3     7.1   8.0
# 999        龍潭    桃園市   25       NaN     良好  1.0  0.11   9.6    10.6  14.0
#
#      ...  winddirec  datacreationdate  unit  co_8hr pm2.5_avg pm10_avg  \
# ...

# %%
df.dtypes
# Out:
# sitename             object
# county               object
# aqi                   int64
# pollutant            object
# status               object
# so2                 float64
# co                  float64
# o3                  float64
# o3_8hr              float64
# pm10                float64
# pm2.5               float64
# no2                 float64
# nox                 float64
# no                  float64
# windspeed            object
# winddirec            object
# datacreationdate     object
# unit                float64
# co_8hr              float64
# pm2.5_avg           float64
# pm10_avg            float64
# so2_avg             float64
# longitude           float64
# latitude            float64
# siteid                int64
# dtype: object
